# %% [markdown]
# ![](Chapter1_1.jpg)![Chapter1_1.JPG](attachment:Chapter1_1.JPG)

# %%
print("Welcome to Python.\nWelcome to Computer Science.\nProgramming is fun.")
# Out:
# Welcome to Python.
# Welcome to Computer Science.
# Programming is fun.

# %% [markdown]
# ![Chapter1_2.JPG](attachment:Chapter1_2.JPG)

# %%
for i in range(5):
    print("Welcome to Python.")
# Out:
# Welcome to Python.
# Welcome to Python.
# Welcome to Python.
# Welcome to Python.
# Welcome to Python.

# %% [markdown]
# ![Chapter1_3.JPG](attachment:Chapter1_3.JPG)

# %%
print("FFFFFFF   U     U   NN    NN")
print("FF        U     U   NNN   NN")
print("FFFFFFF   U     U   NN N  NN")
print("FF         U   U    NN  N NN")
print("FF          UUU     NN   NNN")
# Out:
# FFFFFFF   U     U   NN    NN
# FF        U     U   NNN   NN
# FFFFFFF   U     U   NN N  NN
# FF         U   U    NN  N NN
# FF          UUU     NN   NNN

# %% [markdown]
# ![Chapter1_4.JPG](attachment:Chapter1_4.JPG)

# %%
print("a\ta^2\ta^3")
for a in range(1, 5, 1):
    print(a,"\t",a*a,"\t",a*a*a)
# Out:
# a	a^2	a^3
# 1 	 1 	 1
# 2 	 4 	 8
# 3 	 9 	 27
# 4 	 16 	 64

# %% [markdown]
# ![Chapter1_5.JPG](attachment:Chapter1_5.JPG)

# %%
print((9.5 * 4.5 - 2.5 * 3) / (45.5 - 3.5))
# Out:
# 0.8392857142857143

# %% [markdown]
# ![Chapter1_6.JPG](attachment:Chapter1_6.JPG)

# %%
sum = 0;
for i in range(1, 10):
    sum += i
print (sum)
# Out:
# 45

# %% [markdown]
# ![Chapter1_7.JPG](attachment:Chapter1_7.JPG)

# %%
print(4 * (1 - 1/3 + 1/5 - 1/7 + 1/9 - 1/11))
print(4 * (1 - 1/3 + 1/5 - 1/7 + 1/9 - 1/11 + 1/13 - 1/15))
# Out:
# 2.9760461760461765
# 3.017071817071818

# %% [markdown]
# ![Chapter1_8.JPG](attachment:Chapter1_8.JPG)

# %%
import math
radius = 5.5
print("Area is ", radius * radius * math.pi)
print("Perimeter is ", 2 * radius * math.pi)
# Out:
# Area is  95.03317777109125
# Perimeter is  34.55751918948772

# %% [markdown]
# ![Chapter1_9.JPG](attachment:Chapter1_9.JPG)

# %%
width = 4.5
height = 7.9
area = width * height
perimeter = (width + height)*2
print("Area is ", area)
print("Perimeter ", perimeter)
# Out:
# Area is  35.550000000000004
# Perimeter  24.8

# %% [markdown]
# ![Chapter1_10.JPG](attachment:Chapter1_10.JPG)

# %%
km_mile = 14 / 1.6
speed = ((45 * 60) + 30) /3600
average = km_mile / speed
print("Average is ", average)
# Out:
# Average is  11.538461538461538

# %% [markdown]
# ![Chapter1_11.JPG](attachment:Chapter1_11.JPG)
